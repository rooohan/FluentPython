# %% [markdown]
# # 第11章 描述符descriptor
#
# 描述符是Python对象模型中的一种特殊协议，主要和4个魔术方法有关：`__get__ __set__ __delete__ __set_name__`。
#
# 任何一个实现了`__get__ __set__ __delete__`其中之一的类，都可以称为描述符类，它的实例则称为描述符对象。
#
# 要使用一个描述符，最常见的方法是把它的实例对象设置为其他类（常被称为owner类）的属性。
#
# ## 11.1 \_\_get\_\_
#
# 描述符的`__get__(self, instance, owner=None)`方法，会在访问`owner`类或`owner`类实例的对应属性时被触发，其方法的两个参数含义如下：
#
# - instance：如果用类的实例来访问描述符属性，此参数为类的实例对象；如果通过类本身访问，该值为None。
# - owner：描述符对象所绑定的类

# %%
class InfoDescriptor:
    """描述符类"""
    
    def __get__(self, instance, owner=None):
        print(f"描述符的__get__, instance: {str(instance.__class__.__name__)}, owner: {owner}")
        if not instance:
            print("没有实例的调用")
            return self
        
        # 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。
        return 10

# %%
class MyABC:
    """使用描述符的类"""
    bar = InfoDescriptor()
    
    def __init__(self):
        self.x = 5


MyABC().bar
vars(MyABC())
# Out:
# 描述符的__get__, instance: MyABC, owner: <class '__main__.MyABC'>
# {'x': 5}

# %%
MyABC.bar
# Out:
# 描述符的__get__, instance: NoneType, owner: <class '__main__.MyABC'>
# 没有实例的调用

# %% [markdown]
# 从上述代码，我们可以看到：
#
# 因为描述符是绑定到类中，以获取属性实例化的形式存在的。所以`owner`总是能返回被绑定的类；
#
# 只有当通过被绑定的类的实例访问时，`instance` 才返回了值。
#
#
# ## 11.2 \_\_set\_\_
#
# 与`__get__`类似，`__set__`是在类修改绑定的描述符属性时，触发的行为。`__set__`方法后的参数含义如下：
#
# - instance：属性当前绑定的实例对象
# - value：待设置的属性值
#
# 与`__get__`方法不同，`__set__`仅对实例修改有效。对类修改描述符无效。
#
# 描述器的一种流行用法是托管对实例数据的访问。描述器被分配给类字典中的公开属性，而实际数据作为私有属性存储在实例字典中。当访问公开属性时，会触发描述器的 `__get__()` 和 `__set__()` 方法。
#
# 在下面的例子中，age 是公开属性，_age 是私有属性。当访问公开属性时，描述器会记录下查找或更新的日志：

# %%
import logging

logging.basicConfig(level=logging.INFO)

class LoggedAgeAccess:

    def __get__(self, obj, objtype=None):
        value = obj._age
        logging.info('Accessing %r giving %r', 'age', value)
        return value

    def __set__(self, obj, value):
        logging.info('Updating %r to %r', 'age', value)
        obj._age = value

class Person:

    age = LoggedAgeAccess()             # Descriptor instance

    def __init__(self, name, age):
        self.name = name                # Regular instance attribute
        self.age = age                  # Calls __set__()

    def birthday(self):
        self.age += 1                   # Calls both __get__() and __set__()

# %%
mary = Person('Mary M', 30)
dave = Person('David D', 40)
mary.age
mary.birthday()
vars(mary)
# Out:
# INFO:root:Updating 'name' to 'Mary M'
# INFO:root:Updating 'age' to 30
# INFO:root:Updating 'name' to 'David D'
# INFO:root:Updating 'age' to 40
# INFO:root:Accessing 'age' giving 30
# INFO:root:Accessing 'age' giving 30
# INFO:root:Updating 'age' to 31
# {'_name': 'Mary M', '_age': 31}

# %% [markdown]
# 此示例的一个主要问题是私有名称 _age 在类 LoggedAgeAccess 中是硬耦合的。这意味着每个实例只能有一个用于记录的属性，并且其名称不可更改。
#
# ## 11.3 \_\_set_name\_\_
#
# Python3.6 新增方法，它接受以下两个参数：
# - owner：描述符类当前绑定的类
# - name： 描述符所绑定的属性名称
#
# __set_name__的触发时机是owner类被创建的时候。
#
# 在下面的例子中，Person 类具有两个描述器实例 name 和 age。当类 Person 被定义的时候，他回调了 LoggedAccess 中的 __set_name__() 来记录字段名称，让每个描述器拥有自己的 public_name 和 private_name：

# %%
import logging

logging.basicConfig(level=logging.INFO)

class LoggedAccess:

    def __set_name__(self, owner, name):
        self.public_name = name
        self.private_name = '_' + name

    def __get__(self, obj, objtype=None):
        value = getattr(obj, self.private_name)
        logging.info('Accessing %r giving %r', self.public_name, value)
        return value

    def __set__(self, obj, value):
        logging.info('Updating %r to %r', self.public_name, value)
        setattr(obj, self.private_name, value)

class Person:

    name = LoggedAccess()                # First descriptor instance
    age = LoggedAccess()                 # Second descriptor instance

    def __init__(self, name, age):
        self.name = name                 # Calls the first descriptor
        self.age = age                   # Calls the second descriptor

    def birthday(self):
        self.age += 1

# %%
vars(vars(Person)['name'])
# Out:
# {'public_name': 'name', 'private_name': '_name'}

# %%
vars(vars(Person)['age'])
# Out:
# {'public_name': 'age', 'private_name': '_age'}

# %%
vars(Person)['name']

# %%
locals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'class InfoDescriptor:\n    """描述符类"""\n    \n    def __get__(self, instance, owner=None):\n        print(f"描述符的__get__, instance: {instance}, owner: {instance}")\n        if not instance：\n            print("没有实例的调用")\n            return self\n        return \'infomative descriptor\'\n    ',
#   'class InfoDescriptor:\n    """描述符类"""\n    \n    def __get__(self, instance, owner=None):\n        print(f"描述符的__get__, instance: {instance}, owner: {instance}")\n        if not instance：\n            print("没有实例的调用")\n            return self\n        return \'infomative descriptor\'\n    ',
#   'class InfoDescriptor:\n    """描述符类"""\n    \n    def __get__(self, instance, owner=None):\n        print(f"描述符的__get__, instance: {instance}, owner: {instance}")\n        if not instance:\n            print("没有实例的调用")\n            return self\n        return \'infomative descriptor\'\n    ',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \nmy_instance = MyABC()\nmy_instance.bar',
#   'class InfoDescriptor:\n    """描述符类"""\n    \n    def __get__(self, instance, owner=None):\n        print(f"描述符的__get__, instance: {instance}, owner: {owner}")\n        if not instance:\n            print("没有实例的调用")\n            return self\n        return \'infomative descriptor\'\n    ',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \nmy_instance = MyABC()\nmy_instance.bar',
#   'class InfoDescriptor:\n    """描述符类"""\n    \n    def __get__(self, instance, owner=None):\n        print(f"描述符的__get__, instance: {str(instance)}, owner: {owner}")\n        if not instance:\n            print("没有实例的调用")\n            return self\n        return \'infomative descriptor\'\n    ',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    def __repr__():\n        return "MyABC"\n    \nmy_instance = MyABC()\nmy_instance.bar',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    def __repr__(self):\n        return "MyABC"\n    \nmy_instance = MyABC()\nmy_instance.bar',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    def __repr__(self):\n        return "MyABC"\n    \nmy_instance = MyABC()\nmy_instance.bar\nmy_instance',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    def __repr__(self):\n        return "MyABC"\n    \nmy_instance = MyABC()\nmy_instance.bar\nMyABC()',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    def __repr__(self):\n        return "MyABC"\n    \nmy_instance = MyABC()\nmy_instance.bar\nMyABC',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    \nmy_instance = MyABC()\nmy_instance.bar',
#   'MyABC.bar',
#   'class InfoDescriptor:\n    """描述符类"""\n    \n    def __get__(self, instance, owner=None):\n        print(f"描述符的__get__, instance: {str(instance.__name__)}, owner: {owner}")\n        if not instance:\n            print("没有实例的调用")\n            return self\n        return \'infomative descriptor\'\n    ',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    \nmy_instance = MyABC()\nmy_instance.bar',
#   'class InfoDescriptor:\n    """描述符类"""\n    \n    def __get__(self, instance, owner=None):\n        print(f"描述符的__get__, instance: {str(instance.__class__.__name__)}, owner: {owner}")\n        if not instance:\n            print("没有实例的调用")\n            return self\n        return \'infomative descriptor\'\n    ',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    \nmy_instance = MyABC()\nmy_instance.bar',
#   'class InfoDescriptor:\n    """描述符类"""\n    \n    def __get__(self, instance, owner=None):\n        print(f"描述符的__get__, instance: {str(instance.__class__.__name__)}, owner: {owner__class__.__name__}")\n        if not instance:\n            print("没有实例的调用")\n            return self\n        return \'infomative descriptor\'\n    ',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    \nmy_instance = MyABC()\nmy_instance.bar',
#   'class InfoDescriptor:\n    """描述符类"""\n    \n    def __get__(self, instance, owner=None):\n        print(f"描述符的__get__, instance: {str(instance.__class__.__name__)}, owner: {owner.__class__.__name__}")\n        if not instance:\n            print("没有实例的调用")\n            return self\n        return \'infomative descriptor\'\n    ',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    \nmy_instance = MyABC()\nmy_instance.bar',
#   'MyABC.bar',
#   'MyABC.bar\ndir(my_instance)',
#   'MyABC.bar\ndir(my_instance.__class__)',
#   'MyABC.bar\ndir(my_instance)',
#   'MyABC.bar\nmy_instance.__class__',
#   'MyABC.bar\nmy_instance.__dict__',
#   'MyABC.bar',
#   'class InfoDescriptor:\n    """描述符类"""\n    \n    def __get__(self, instance, owner=None):\n        print(f"描述符的__get__, instance: {str(instance.__class__.__name__)}, owner: {owner}")\n        if not instance:\n            print("没有实例的调用")\n            return self\n        return \'infomative descriptor\'\n    ',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    \nmy_instance = MyABC()\nmy_instance.bar',
#   'class InfoDescriptor:\n    """描述符类"""\n    \n    def __get__(self, instance, owner=None):\n        print(f"描述符的__get__, instance: {str(instance.__class__.__name__)}, owner: {owner}")\n        if not instance:\n            print("没有实例的调用")\n            return self\n        return 10\n    ',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    \nmy_instance = MyABC()\nmy_instance.bar',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars（my_instance）',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    x=5\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    x=5\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    x=5\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)\nmy_instance.__dict__',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    x=5\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)\nMyABC.__dict__',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    def __init__():\n        self.x = 5\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)\nMyABC.__dict__',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    def __init__(self):\n        self.x = 5\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)\nMyABC.__dict__',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    def __init__(self):\n        self.x = 5\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)',
#   'class MyABC:\n    """使用描述符的类"""\n    _bar = InfoDescriptor()\n    \n    def __init__(self):\n        self.x = 5\n        self.bar = _bar\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)',
#   'class MyABC:\n    """使用描述符的类"""\n    _bar = InfoDescriptor()\n    \n    def __init__(self):\n        self.x = 5\n        self.bar = _bar\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)',
#   'MyABC.bar',
#   'class MyABC:\n    """使用描述符的类"""\n    _bar = InfoDescriptor()\n    \n    def __init__(self):\n        self.x = 5\n        self.bar = _bar\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)',
#   'class MyABC:\n    """使用描述符的类"""\n    _bar = InfoDescriptor()\n    \n    def __init__(self):\n        self.x = 5\n        self.bar = 3\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)',
#   'MyABC.bar',
#   'class MyABC:\n    """使用描述符的类"""\n    _bar = InfoDescriptor()\n    \n    def __init__(self):\n        self.x = 5\n        self.bar = _bar\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)',
#   'class MyABC:\n    """使用描述符的类"""\n    _bar = InfoDescriptor()\n    \n    def __init__(self):\n        self.x = 5\n        self.bar = _bar\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nvars(my_instance)',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    def __init__(self):\n        self.x = 5\n        self.bar = bar\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    def __init__(self):\n        nonlocal bar\n        self.x = 5\n        self.bar = bar\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    def __init__(self):\n        global bar\n        self.x = 5\n        self.bar = bar\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    y = 6\n    \n    def __init__(self):\n        self.x = 5\n#         self.bar = bar\n        print(y)\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    def __init__(self):\n        self.x = 5\n\n\nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    def __init__(self):\n        self.x = 5\n\n\nMyABC().bar\nvars(MyABC())',
#   'MyABC.bar',
#   "import logging\n\nlogging.basicConfig(level=logging.INFO)\n\nclass LoggedAgeAccess:\n\n    def __get__(self, obj, objtype=None):\n        value = obj._age\n        logging.info('Accessing %r giving %r', 'age', value)\n        return value\n\n    def __set__(self, obj, value):\n        logging.info('Updating %r to %r', 'age', value)\n        obj._age = value\n\nclass Person:\n\n    age = LoggedAgeAccess()             # Descriptor instance\n\n    def __init__(self, name, age):\n        self.name = name                # Regular instance attribute\n        self.age = age                  # Calls __set__()\n\n    def birthday(self):\n        self.age += 1                   # Calls both __get__() and __set__()\n        ",
#   "mary = Person('Mary M', 30)",
#   "mary = Person('Mary M', 30)\ndave = Person('David D', 40)",
#   "mary = Person('Mary M', 30)\ndave = Person('David D', 40)\nvars(mary)",
#   "mary = Person('Mary M', 30)\ndave = Person('David D', 40)\nmary.age\nvars(mary)",
#   "mary = Person('Mary M', 30)\ndave = Person('David D', 40)\nmary.age\nmary.birthday()\nvars(mary)",
#   "import logging\n\nlogging.basicConfig(level=logging.INFO)\n\nclass LoggedAccess:\n\n    def __set_name__(self, owner, name):\n        self.public_name = name\n        self.private_name = '_' + name\n\n    def __get__(self, obj, objtype=None):\n        value = getattr(obj, self.private_name)\n        logging.info('Accessing %r giving %r', self.public_name, value)\n        return value\n\n    def __set__(self, obj, value):\n        logging.info('Updating %r to %r', self.public_name, value)\n        setattr(obj, self.private_name, value)\n\nclass Person:\n\n    name = LoggedAccess()                # First descriptor instance\n    age = LoggedAccess()                 # Second descriptor instance\n\n    def __init__(self, name, age):\n        self.name = name                 # Calls the first descriptor\n        self.age = age                   # Calls the second descriptor\n\n    def birthday(self):\n        self.age += 1",
#   "vars(vars(Person)['name'])",
#   "vars(vars(Person)['name'])\nvars(vars(Person)['age'])",
#   "vars(vars(Person)['name'])",
#   "vars(vars(Person)['age'])",
#   "mary = Person('Mary M', 30)\ndave = Person('David D', 40)\nmary.age\nmary.birthday()\nvars(mary)['age']",
#   "mary = Person('Mary M', 30)\ndave = Person('David D', 40)\nmary.age\nmary.birthday()\nvars(mary)",
#   "mary = Person('Mary M', 30)\ndave = Person('David D', 40)\nmary.age\nmary.birthday()\nvars(mary)['_age']",
#   "mary = Person('Mary M', 30)\ndave = Person('David D', 40)\nmary.age\nmary.birthday()\nvars(mary)",
#   "vars(Person)['name']",
#   'from utils.collections import AttrDict',
#   'from collections import AttrDict',
#   'vars()',
#   'locals()'],
#  '_oh': {4: 'infomative descriptor',
#   6: 'infomative descriptor',
#   9: 'infomative descriptor',
#   10: MyABC,
#   11: MyABC,
#   12: __main__.MyABC,
#   13: 'infomative descriptor',
#   14: <__main__.InfoDescriptor at 0x107142fd0>,
#   18: 'infomative descriptor',
#   22: 'infomative descriptor',
#   23: <__main__.InfoDescriptor at 0x106e91970>,
#   24: ['__class__',
#    '__delattr__',
#    '__dict__',
#    '__dir__',
#    '__doc__',
#    '__eq__',
#    '__format__',
#    '__ge__',
#    '__getattribute__',
#    '__gt__',
#    '__hash__',
#    '__init__',
#    '__init_subclass__',
#    '__le__',
#    '__lt__',
#    '__module__',
#    '__ne__',
#    '__new__',
#    '__reduce__',
#    '__reduce_ex__',
#    '__repr__',
#    '__setattr__',
#    '__sizeof__',
#    '__str__',
#    '__subclasshook__',
#    '__weakref__',
#    'bar'],
#   25: ['__class__',
#    '__delattr__',
#    '__dict__',
#    '__dir__',
#    '__doc__',
#    '__eq__',
#    '__format__',
#    '__ge__',
#    '__getattribute__',
#    '__gt__',
#    '__hash__',
#    '__init__',
#    '__init_subclass__',
#    '__le__',
#    '__lt__',
#    '__module__',
#    '__ne__',
#    '__new__',
#    '__reduce__',
#    '__reduce_ex__',
#    '__repr__',
#    '__setattr__',
#    '__sizeof__',
#    '__str__',
#    '__subclasshook__',
#    '__weakref__',
#    'bar'],
#   26: ['__class__',
#    '__delattr__',
#    '__dict__',
#    '__dir__',
#    '__doc__',
#    '__eq__',
#    '__format__',
#    '__ge__',
#    '__getattribute__',
#    '__gt__',
#    '__hash__',
#    '__init__',
#    '__init_subclass__',
#    '__le__',
#    '__lt__',
#    '__module__',
#    '__ne__',
#    '__new__',
#    '__reduce__',
#    '__reduce_ex__',
#    '__repr__',
#    '__setattr__',
#    '__sizeof__',
#    '__str__',
#    '__subclasshook__',
#    '__weakref__',
#    'bar'],
#   27: __main__.MyABC,
#   28: {},
#   29: <__main__.InfoDescriptor at 0x106e91970>,
#   31: 'infomative descriptor',
#   33: 10,
#   35: {},
#   36: {},
#   37: {},
#   38: {},
#   39: mappingproxy({'__module__': '__main__',
#                 '__doc__': '使用描述符的类',
#                 'bar': <__main__.InfoDescriptor at 0x106e8ffa0>,
#                 'x': 5,
#                 '__dict__': <attribute '__dict__' of 'MyABC' objects>,
#                 '__weakref__': <attribute '__weakref__' of 'MyABC' objects>}),
#   41: mappingproxy({'__module__': '__main__',
#                 '__doc__': '使用描述符的类',
#                 'bar': <__main__.InfoDescriptor at 0x1070962b0>,
#                 '__init__': <function __main__.MyABC.__init__(self)>,
#                 '__dict__': <attribute '__dict__' of 'MyABC' objects>,
#                 '__weakref__': <attribute '__weakref__' of 'MyABC' objects>}),
#   42: {'x': 5},
#   47: {'x': 5, 'bar': 3},
#   55: {'x': 5},
#   56: {'x': 5},
#   57: <__main__.InfoDescriptor at 0x106d9ee20>,
#   61: {'name': 'Mary M', '_age': 30},
#   62: {'name': 'Mary M', '_age': 30},
#   63: {'name': 'Mary M', '_age': 31},
#   65: {'public_name': 'name', 'private_name': '_name'},
#   66: {'public_name': 'age', 'private_name': '_age'},
#   67: {'public_name': 'name', 'private_name': '_name'},
#   68: {'public_name': 'age', 'private_name': '_age'},
#   70: {'_name': 'Mary M', '_age': 31},
#   71: 31,
#   72: {'_name': 'Mary M', '_age': 31},
#   73: <__main__.LoggedAccess at 0x106d9e040>,
#   76: {...}},
#  '_dh': [PosixPath('/Users/rohan/Documents/Code/Python/Python Artizan')],
#  'In': ['',
#   'class InfoDescriptor:\n    """描述符类"""\n    \n    def __get__(self, instance, owner=None):\n        print(f"描述符的__get__, instance: {instance}, owner: {instance}")\n        if not instance：\n            print("没有实例的调用")\n            return self\n        return \'infomative descriptor\'\n    ',
#   'class InfoDescriptor:\n    """描述符类"""\n    \n    def __get__(self, instance, owner=None):\n        print(f"描述符的__get__, instance: {instance}, owner: {instance}")\n        if not instance：\n            print("没有实例的调用")\n            return self\n        return \'infomative descriptor\'\n    ',
#   'class InfoDescriptor:\n    """描述符类"""\n    \n    def __get__(self, instance, owner=None):\n        print(f"描述符的__get__, instance: {instance}, owner: {instance}")\n        if not instance:\n            print("没有实例的调用")\n            return self\n        return \'infomative descriptor\'\n    ',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \nmy_instance = MyABC()\nmy_instance.bar',
#   'class InfoDescriptor:\n    """描述符类"""\n    \n    def __get__(self, instance, owner=None):\n        print(f"描述符的__get__, instance: {instance}, owner: {owner}")\n        if not instance:\n            print("没有实例的调用")\n            return self\n        return \'infomative descriptor\'\n    ',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \nmy_instance = MyABC()\nmy_instance.bar',
#   'class InfoDescriptor:\n    """描述符类"""\n    \n    def __get__(self, instance, owner=None):\n        print(f"描述符的__get__, instance: {str(instance)}, owner: {owner}")\n        if not instance:\n            print("没有实例的调用")\n            return self\n        return \'infomative descriptor\'\n    ',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    def __repr__():\n        return "MyABC"\n    \nmy_instance = MyABC()\nmy_instance.bar',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    def __repr__(self):\n        return "MyABC"\n    \nmy_instance = MyABC()\nmy_instance.bar',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    def __repr__(self):\n        return "MyABC"\n    \nmy_instance = MyABC()\nmy_instance.bar\nmy_instance',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    def __repr__(self):\n        return "MyABC"\n    \nmy_instance = MyABC()\nmy_instance.bar\nMyABC()',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    def __repr__(self):\n        return "MyABC"\n    \nmy_instance = MyABC()\nmy_instance.bar\nMyABC',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    \nmy_instance = MyABC()\nmy_instance.bar',
#   'MyABC.bar',
#   'class InfoDescriptor:\n    """描述符类"""\n    \n    def __get__(self, instance, owner=None):\n        print(f"描述符的__get__, instance: {str(instance.__name__)}, owner: {owner}")\n        if not instance:\n            print("没有实例的调用")\n            return self\n        return \'infomative descriptor\'\n    ',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    \nmy_instance = MyABC()\nmy_instance.bar',
#   'class InfoDescriptor:\n    """描述符类"""\n    \n    def __get__(self, instance, owner=None):\n        print(f"描述符的__get__, instance: {str(instance.__class__.__name__)}, owner: {owner}")\n        if not instance:\n            print("没有实例的调用")\n            return self\n        return \'infomative descriptor\'\n    ',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    \nmy_instance = MyABC()\nmy_instance.bar',
#   'class InfoDescriptor:\n    """描述符类"""\n    \n    def __get__(self, instance, owner=None):\n        print(f"描述符的__get__, instance: {str(instance.__class__.__name__)}, owner: {owner__class__.__name__}")\n        if not instance:\n            print("没有实例的调用")\n            return self\n        return \'infomative descriptor\'\n    ',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    \nmy_instance = MyABC()\nmy_instance.bar',
#   'class InfoDescriptor:\n    """描述符类"""\n    \n    def __get__(self, instance, owner=None):\n        print(f"描述符的__get__, instance: {str(instance.__class__.__name__)}, owner: {owner.__class__.__name__}")\n        if not instance:\n            print("没有实例的调用")\n            return self\n        return \'infomative descriptor\'\n    ',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    \nmy_instance = MyABC()\nmy_instance.bar',
#   'MyABC.bar',
#   'MyABC.bar\ndir(my_instance)',
#   'MyABC.bar\ndir(my_instance.__class__)',
#   'MyABC.bar\ndir(my_instance)',
#   'MyABC.bar\nmy_instance.__class__',
#   'MyABC.bar\nmy_instance.__dict__',
#   'MyABC.bar',
#   'class InfoDescriptor:\n    """描述符类"""\n    \n    def __get__(self, instance, owner=None):\n        print(f"描述符的__get__, instance: {str(instance.__class__.__name__)}, owner: {owner}")\n        if not instance:\n            print("没有实例的调用")\n            return self\n        return \'infomative descriptor\'\n    ',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    \nmy_instance = MyABC()\nmy_instance.bar',
#   'class InfoDescriptor:\n    """描述符类"""\n    \n    def __get__(self, instance, owner=None):\n        print(f"描述符的__get__, instance: {str(instance.__class__.__name__)}, owner: {owner}")\n        if not instance:\n            print("没有实例的调用")\n            return self\n        return 10\n    ',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    \nmy_instance = MyABC()\nmy_instance.bar',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars（my_instance）',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    x=5\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    x=5\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    x=5\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)\nmy_instance.__dict__',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    x=5\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)\nMyABC.__dict__',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    def __init__():\n        self.x = 5\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)\nMyABC.__dict__',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    def __init__(self):\n        self.x = 5\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)\nMyABC.__dict__',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    def __init__(self):\n        self.x = 5\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)',
#   'class MyABC:\n    """使用描述符的类"""\n    _bar = InfoDescriptor()\n    \n    def __init__(self):\n        self.x = 5\n        self.bar = _bar\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)',
#   'class MyABC:\n    """使用描述符的类"""\n    _bar = InfoDescriptor()\n    \n    def __init__(self):\n        self.x = 5\n        self.bar = _bar\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)',
#   'MyABC.bar',
#   'class MyABC:\n    """使用描述符的类"""\n    _bar = InfoDescriptor()\n    \n    def __init__(self):\n        self.x = 5\n        self.bar = _bar\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)',
#   'class MyABC:\n    """使用描述符的类"""\n    _bar = InfoDescriptor()\n    \n    def __init__(self):\n        self.x = 5\n        self.bar = 3\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)',
#   'MyABC.bar',
#   'class MyABC:\n    """使用描述符的类"""\n    _bar = InfoDescriptor()\n    \n    def __init__(self):\n        self.x = 5\n        self.bar = _bar\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)',
#   'class MyABC:\n    """使用描述符的类"""\n    _bar = InfoDescriptor()\n    \n    def __init__(self):\n        self.x = 5\n        self.bar = _bar\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nvars(my_instance)',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    def __init__(self):\n        self.x = 5\n        self.bar = bar\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    def __init__(self):\n        nonlocal bar\n        self.x = 5\n        self.bar = bar\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    def __init__(self):\n        global bar\n        self.x = 5\n        self.bar = bar\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    y = 6\n    \n    def __init__(self):\n        self.x = 5\n#         self.bar = bar\n        print(y)\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    def __init__(self):\n        self.x = 5\n\n\nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)',
#   'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    def __init__(self):\n        self.x = 5\n\n\nMyABC().bar\nvars(MyABC())',
#   'MyABC.bar',
#   "import logging\n\nlogging.basicConfig(level=logging.INFO)\n\nclass LoggedAgeAccess:\n\n    def __get__(self, obj, objtype=None):\n        value = obj._age\n        logging.info('Accessing %r giving %r', 'age', value)\n        return value\n\n    def __set__(self, obj, value):\n        logging.info('Updating %r to %r', 'age', value)\n        obj._age = value\n\nclass Person:\n\n    age = LoggedAgeAccess()             # Descriptor instance\n\n    def __init__(self, name, age):\n        self.name = name                # Regular instance attribute\n        self.age = age                  # Calls __set__()\n\n    def birthday(self):\n        self.age += 1                   # Calls both __get__() and __set__()\n        ",
#   "mary = Person('Mary M', 30)",
#   "mary = Person('Mary M', 30)\ndave = Person('David D', 40)",
#   "mary = Person('Mary M', 30)\ndave = Person('David D', 40)\nvars(mary)",
#   "mary = Person('Mary M', 30)\ndave = Person('David D', 40)\nmary.age\nvars(mary)",
#   "mary = Person('Mary M', 30)\ndave = Person('David D', 40)\nmary.age\nmary.birthday()\nvars(mary)",
#   "import logging\n\nlogging.basicConfig(level=logging.INFO)\n\nclass LoggedAccess:\n\n    def __set_name__(self, owner, name):\n        self.public_name = name\n        self.private_name = '_' + name\n\n    def __get__(self, obj, objtype=None):\n        value = getattr(obj, self.private_name)\n        logging.info('Accessing %r giving %r', self.public_name, value)\n        return value\n\n    def __set__(self, obj, value):\n        logging.info('Updating %r to %r', self.public_name, value)\n        setattr(obj, self.private_name, value)\n\nclass Person:\n\n    name = LoggedAccess()                # First descriptor instance\n    age = LoggedAccess()                 # Second descriptor instance\n\n    def __init__(self, name, age):\n        self.name = name                 # Calls the first descriptor\n        self.age = age                   # Calls the second descriptor\n\n    def birthday(self):\n        self.age += 1",
#   "vars(vars(Person)['name'])",
#   "vars(vars(Person)['name'])\nvars(vars(Person)['age'])",
#   "vars(vars(Person)['name'])",
#   "vars(vars(Person)['age'])",
#   "mary = Person('Mary M', 30)\ndave = Person('David D', 40)\nmary.age\nmary.birthday()\nvars(mary)['age']",
#   "mary = Person('Mary M', 30)\ndave = Person('David D', 40)\nmary.age\nmary.birthday()\nvars(mary)",
#   "mary = Person('Mary M', 30)\ndave = Person('David D', 40)\nmary.age\nmary.birthday()\nvars(mary)['_age']",
#   "mary = Person('Mary M', 30)\ndave = Person('David D', 40)\nmary.age\nmary.birthday()\nvars(mary)",
#   "vars(Person)['name']",
#   'from utils.collections import AttrDict',
#   'from collections import AttrDict',
#   'vars()',
#   'locals()'],
#  'Out': {4: 'infomative descriptor',
#   6: 'infomative descriptor',
#   9: 'infomative descriptor',
#   10: MyABC,
#   11: MyABC,
#   12: __main__.MyABC,
#   13: 'infomative descriptor',
#   14: <__main__.InfoDescriptor at 0x107142fd0>,
#   18: 'infomative descriptor',
#   22: 'infomative descriptor',
#   23: <__main__.InfoDescriptor at 0x106e91970>,
#   24: ['__class__',
#    '__delattr__',
#    '__dict__',
#    '__dir__',
#    '__doc__',
#    '__eq__',
#    '__format__',
#    '__ge__',
#    '__getattribute__',
#    '__gt__',
#    '__hash__',
#    '__init__',
#    '__init_subclass__',
#    '__le__',
#    '__lt__',
#    '__module__',
#    '__ne__',
#    '__new__',
#    '__reduce__',
#    '__reduce_ex__',
#    '__repr__',
#    '__setattr__',
#    '__sizeof__',
#    '__str__',
#    '__subclasshook__',
#    '__weakref__',
#    'bar'],
#   25: ['__class__',
#    '__delattr__',
#    '__dict__',
#    '__dir__',
#    '__doc__',
#    '__eq__',
#    '__format__',
#    '__ge__',
#    '__getattribute__',
#    '__gt__',
#    '__hash__',
#    '__init__',
#    '__init_subclass__',
#    '__le__',
#    '__lt__',
#    '__module__',
#    '__ne__',
#    '__new__',
#    '__reduce__',
#    '__reduce_ex__',
#    '__repr__',
#    '__setattr__',
#    '__sizeof__',
#    '__str__',
#    '__subclasshook__',
#    '__weakref__',
#    'bar'],
#   26: ['__class__',
#    '__delattr__',
#    '__dict__',
#    '__dir__',
#    '__doc__',
#    '__eq__',
#    '__format__',
#    '__ge__',
#    '__getattribute__',
#    '__gt__',
#    '__hash__',
#    '__init__',
#    '__init_subclass__',
#    '__le__',
#    '__lt__',
#    '__module__',
#    '__ne__',
#    '__new__',
#    '__reduce__',
#    '__reduce_ex__',
#    '__repr__',
#    '__setattr__',
#    '__sizeof__',
#    '__str__',
#    '__subclasshook__',
#    '__weakref__',
#    'bar'],
#   27: __main__.MyABC,
#   28: {},
#   29: <__main__.InfoDescriptor at 0x106e91970>,
#   31: 'infomative descriptor',
#   33: 10,
#   35: {},
#   36: {},
#   37: {},
#   38: {},
#   39: mappingproxy({'__module__': '__main__',
#                 '__doc__': '使用描述符的类',
#                 'bar': <__main__.InfoDescriptor at 0x106e8ffa0>,
#                 'x': 5,
#                 '__dict__': <attribute '__dict__' of 'MyABC' objects>,
#                 '__weakref__': <attribute '__weakref__' of 'MyABC' objects>}),
#   41: mappingproxy({'__module__': '__main__',
#                 '__doc__': '使用描述符的类',
#                 'bar': <__main__.InfoDescriptor at 0x1070962b0>,
#                 '__init__': <function __main__.MyABC.__init__(self)>,
#                 '__dict__': <attribute '__dict__' of 'MyABC' objects>,
#                 '__weakref__': <attribute '__weakref__' of 'MyABC' objects>}),
#   42: {'x': 5},
#   47: {'x': 5, 'bar': 3},
#   55: {'x': 5},
#   56: {'x': 5},
#   57: <__main__.InfoDescriptor at 0x106d9ee20>,
#   61: {'name': 'Mary M', '_age': 30},
#   62: {'name': 'Mary M', '_age': 30},
#   63: {'name': 'Mary M', '_age': 31},
#   65: {'public_name': 'name', 'private_name': '_name'},
#   66: {'public_name': 'age', 'private_name': '_age'},
#   67: {'public_name': 'name', 'private_name': '_name'},
#   68: {'public_name': 'age', 'private_name': '_age'},
#   70: {'_name': 'Mary M', '_age': 31},
#   71: 31,
#   72: {'_name': 'Mary M', '_age': 31},
#   73: <__main__.LoggedAccess at 0x106d9e040>,
#   76: {...}},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x1062d1130>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x1062ef0a0>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x1062ef0a0>,
#  '_': {...},
#  '__': <__main__.LoggedAccess at 0x106d9e040>,
#  '___': {'_name': 'Mary M', '_age': 31},
#  '_i': 'vars()',
#  '_ii': 'from collections import AttrDict',
#  '_iii': 'from utils.collections import AttrDict',
#  '_i1': 'class InfoDescriptor:\n    """描述符类"""\n    \n    def __get__(self, instance, owner=None):\n        print(f"描述符的__get__, instance: {instance}, owner: {instance}")\n        if not instance：\n            print("没有实例的调用")\n            return self\n        return \'infomative descriptor\'\n    ',
#  '_i2': 'class InfoDescriptor:\n    """描述符类"""\n    \n    def __get__(self, instance, owner=None):\n        print(f"描述符的__get__, instance: {instance}, owner: {instance}")\n        if not instance：\n            print("没有实例的调用")\n            return self\n        return \'infomative descriptor\'\n    ',
#  '_i3': 'class InfoDescriptor:\n    """描述符类"""\n    \n    def __get__(self, instance, owner=None):\n        print(f"描述符的__get__, instance: {instance}, owner: {instance}")\n        if not instance:\n            print("没有实例的调用")\n            return self\n        return \'infomative descriptor\'\n    ',
#  'InfoDescriptor': __main__.InfoDescriptor,
#  '_i4': 'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \nmy_instance = MyABC()\nmy_instance.bar',
#  'MyABC': __main__.MyABC,
#  'my_instance': <__main__.MyABC at 0x106783070>,
#  '_4': 'infomative descriptor',
#  '_i5': 'class InfoDescriptor:\n    """描述符类"""\n    \n    def __get__(self, instance, owner=None):\n        print(f"描述符的__get__, instance: {instance}, owner: {owner}")\n        if not instance:\n            print("没有实例的调用")\n            return self\n        return \'infomative descriptor\'\n    ',
#  '_i6': 'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \nmy_instance = MyABC()\nmy_instance.bar',
#  '_6': 'infomative descriptor',
#  '_i7': 'class InfoDescriptor:\n    """描述符类"""\n    \n    def __get__(self, instance, owner=None):\n        print(f"描述符的__get__, instance: {str(instance)}, owner: {owner}")\n        if not instance:\n            print("没有实例的调用")\n            return self\n        return \'infomative descriptor\'\n    ',
#  '_i8': 'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    def __repr__():\n        return "MyABC"\n    \nmy_instance = MyABC()\nmy_instance.bar',
#  '_i9': 'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    def __repr__(self):\n        return "MyABC"\n    \nmy_instance = MyABC()\nmy_instance.bar',
#  '_9': 'infomative descriptor',
#  '_i10': 'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    def __repr__(self):\n        return "MyABC"\n    \nmy_instance = MyABC()\nmy_instance.bar\nmy_instance',
#  '_10': MyABC,
#  '_i11': 'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    def __repr__(self):\n        return "MyABC"\n    \nmy_instance = MyABC()\nmy_instance.bar\nMyABC()',
#  '_11': MyABC,
#  '_i12': 'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    def __repr__(self):\n        return "MyABC"\n    \nmy_instance = MyABC()\nmy_instance.bar\nMyABC',
#  '_12': __main__.MyABC,
#  '_i13': 'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    \nmy_instance = MyABC()\nmy_instance.bar',
#  '_13': 'infomative descriptor',
#  '_i14': 'MyABC.bar',
#  '_14': <__main__.InfoDescriptor at 0x107142fd0>,
#  '_i15': 'class InfoDescriptor:\n    """描述符类"""\n    \n    def __get__(self, instance, owner=None):\n        print(f"描述符的__get__, instance: {str(instance.__name__)}, owner: {owner}")\n        if not instance:\n            print("没有实例的调用")\n            return self\n        return \'infomative descriptor\'\n    ',
#  '_i16': 'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    \nmy_instance = MyABC()\nmy_instance.bar',
#  '_i17': 'class InfoDescriptor:\n    """描述符类"""\n    \n    def __get__(self, instance, owner=None):\n        print(f"描述符的__get__, instance: {str(instance.__class__.__name__)}, owner: {owner}")\n        if not instance:\n            print("没有实例的调用")\n            return self\n        return \'infomative descriptor\'\n    ',
#  '_i18': 'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    \nmy_instance = MyABC()\nmy_instance.bar',
#  '_18': 'infomative descriptor',
#  '_i19': 'class InfoDescriptor:\n    """描述符类"""\n    \n    def __get__(self, instance, owner=None):\n        print(f"描述符的__get__, instance: {str(instance.__class__.__name__)}, owner: {owner__class__.__name__}")\n        if not instance:\n            print("没有实例的调用")\n            return self\n        return \'infomative descriptor\'\n    ',
#  '_i20': 'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    \nmy_instance = MyABC()\nmy_instance.bar',
#  '_i21': 'class InfoDescriptor:\n    """描述符类"""\n    \n    def __get__(self, instance, owner=None):\n        print(f"描述符的__get__, instance: {str(instance.__class__.__name__)}, owner: {owner.__class__.__name__}")\n        if not instance:\n            print("没有实例的调用")\n            return self\n        return \'infomative descriptor\'\n    ',
#  '_i22': 'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    \nmy_instance = MyABC()\nmy_instance.bar',
#  '_22': 'infomative descriptor',
#  '_i23': 'MyABC.bar',
#  '_23': <__main__.InfoDescriptor at 0x106e91970>,
#  '_i24': 'MyABC.bar\ndir(my_instance)',
#  '_24': ['__class__',
#   '__delattr__',
#   '__dict__',
#   '__dir__',
#   '__doc__',
#   '__eq__',
#   '__format__',
#   '__ge__',
#   '__getattribute__',
#   '__gt__',
#   '__hash__',
#   '__init__',
#   '__init_subclass__',
#   '__le__',
#   '__lt__',
#   '__module__',
#   '__ne__',
#   '__new__',
#   '__reduce__',
#   '__reduce_ex__',
#   '__repr__',
#   '__setattr__',
#   '__sizeof__',
#   '__str__',
#   '__subclasshook__',
#   '__weakref__',
#   'bar'],
#  '_i25': 'MyABC.bar\ndir(my_instance.__class__)',
#  '_25': ['__class__',
#   '__delattr__',
#   '__dict__',
#   '__dir__',
#   '__doc__',
#   '__eq__',
#   '__format__',
#   '__ge__',
#   '__getattribute__',
#   '__gt__',
#   '__hash__',
#   '__init__',
#   '__init_subclass__',
#   '__le__',
#   '__lt__',
#   '__module__',
#   '__ne__',
#   '__new__',
#   '__reduce__',
#   '__reduce_ex__',
#   '__repr__',
#   '__setattr__',
#   '__sizeof__',
#   '__str__',
#   '__subclasshook__',
#   '__weakref__',
#   'bar'],
#  '_i26': 'MyABC.bar\ndir(my_instance)',
#  '_26': ['__class__',
#   '__delattr__',
#   '__dict__',
#   '__dir__',
#   '__doc__',
#   '__eq__',
#   '__format__',
#   '__ge__',
#   '__getattribute__',
#   '__gt__',
#   '__hash__',
#   '__init__',
#   '__init_subclass__',
#   '__le__',
#   '__lt__',
#   '__module__',
#   '__ne__',
#   '__new__',
#   '__reduce__',
#   '__reduce_ex__',
#   '__repr__',
#   '__setattr__',
#   '__sizeof__',
#   '__str__',
#   '__subclasshook__',
#   '__weakref__',
#   'bar'],
#  '_i27': 'MyABC.bar\nmy_instance.__class__',
#  '_27': __main__.MyABC,
#  '_i28': 'MyABC.bar\nmy_instance.__dict__',
#  '_28': {},
#  '_i29': 'MyABC.bar',
#  '_29': <__main__.InfoDescriptor at 0x106e91970>,
#  '_i30': 'class InfoDescriptor:\n    """描述符类"""\n    \n    def __get__(self, instance, owner=None):\n        print(f"描述符的__get__, instance: {str(instance.__class__.__name__)}, owner: {owner}")\n        if not instance:\n            print("没有实例的调用")\n            return self\n        return \'infomative descriptor\'\n    ',
#  '_i31': 'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    \nmy_instance = MyABC()\nmy_instance.bar',
#  '_31': 'infomative descriptor',
#  '_i32': 'class InfoDescriptor:\n    """描述符类"""\n    \n    def __get__(self, instance, owner=None):\n        print(f"描述符的__get__, instance: {str(instance.__class__.__name__)}, owner: {owner}")\n        if not instance:\n            print("没有实例的调用")\n            return self\n        return 10\n    ',
#  '_i33': 'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    \nmy_instance = MyABC()\nmy_instance.bar',
#  '_33': 10,
#  '_i34': 'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars（my_instance）',
#  '_i35': 'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)',
#  '_35': {},
#  '_i36': 'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    x=5\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)',
#  '_36': {},
#  '_i37': 'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    x=5\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)',
#  '_37': {},
#  '_i38': 'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    x=5\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)\nmy_instance.__dict__',
#  '_38': {},
#  '_i39': 'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    x=5\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)\nMyABC.__dict__',
#  '_39': mappingproxy({'__module__': '__main__',
#                '__doc__': '使用描述符的类',
#                'bar': <__main__.InfoDescriptor at 0x106e8ffa0>,
#                'x': 5,
#                '__dict__': <attribute '__dict__' of 'MyABC' objects>,
#                '__weakref__': <attribute '__weakref__' of 'MyABC' objects>}),
#  '_i40': 'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    def __init__():\n        self.x = 5\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)\nMyABC.__dict__',
#  '_i41': 'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    def __init__(self):\n        self.x = 5\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)\nMyABC.__dict__',
#  '_41': mappingproxy({'__module__': '__main__',
#                '__doc__': '使用描述符的类',
#                'bar': <__main__.InfoDescriptor at 0x1070962b0>,
#                '__init__': <function __main__.MyABC.__init__(self)>,
#                '__dict__': <attribute '__dict__' of 'MyABC' objects>,
#                '__weakref__': <attribute '__weakref__' of 'MyABC' objects>}),
#  '_i42': 'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    def __init__(self):\n        self.x = 5\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)',
#  '_42': {'x': 5},
#  '_i43': 'class MyABC:\n    """使用描述符的类"""\n    _bar = InfoDescriptor()\n    \n    def __init__(self):\n        self.x = 5\n        self.bar = _bar\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)',
#  '_i44': 'class MyABC:\n    """使用描述符的类"""\n    _bar = InfoDescriptor()\n    \n    def __init__(self):\n        self.x = 5\n        self.bar = _bar\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)',
#  '_i45': 'MyABC.bar',
#  '_i46': 'class MyABC:\n    """使用描述符的类"""\n    _bar = InfoDescriptor()\n    \n    def __init__(self):\n        self.x = 5\n        self.bar = _bar\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)',
#  '_i47': 'class MyABC:\n    """使用描述符的类"""\n    _bar = InfoDescriptor()\n    \n    def __init__(self):\n        self.x = 5\n        self.bar = 3\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)',
#  '_47': {'x': 5, 'bar': 3},
#  '_i48': 'MyABC.bar',
#  '_i49': 'class MyABC:\n    """使用描述符的类"""\n    _bar = InfoDescriptor()\n    \n    def __init__(self):\n        self.x = 5\n        self.bar = _bar\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)',
#  '_i50': 'class MyABC:\n    """使用描述符的类"""\n    _bar = InfoDescriptor()\n    \n    def __init__(self):\n        self.x = 5\n        self.bar = _bar\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nvars(my_instance)',
#  '_i51': 'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    def __init__(self):\n        self.x = 5\n        self.bar = bar\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)',
#  '_i52': 'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    def __init__(self):\n        nonlocal bar\n        self.x = 5\n        self.bar = bar\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)',
#  '_i53': 'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    def __init__(self):\n        global bar\n        self.x = 5\n        self.bar = bar\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)',
#  '_i54': 'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    y = 6\n    \n    def __init__(self):\n        self.x = 5\n#         self.bar = bar\n        print(y)\n    \n    \nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)',
#  '_i55': 'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    def __init__(self):\n        self.x = 5\n\n\nmy_instance = MyABC()\n# 值 10 既不存储在类字典中也不存储在实例字典中。相反，值 10 是在调用时才取到的。\nmy_instance.bar\nvars(my_instance)',
#  '_55': {'x': 5},
#  '_i56': 'class MyABC:\n    """使用描述符的类"""\n    bar = InfoDescriptor()\n    \n    def __init__(self):\n        self.x = 5\n\n\nMyABC().bar\nvars(MyABC())',
#  '_56': {'x': 5},
#  '_i57': 'MyABC.bar',
#  '_57': <__main__.InfoDescriptor at 0x106d9ee20>,
#  '_i58': "import logging\n\nlogging.basicConfig(level=logging.INFO)\n\nclass LoggedAgeAccess:\n\n    def __get__(self, obj, objtype=None):\n        value = obj._age\n        logging.info('Accessing %r giving %r', 'age', value)\n        return value\n\n    def __set__(self, obj, value):\n        logging.info('Updating %r to %r', 'age', value)\n        obj._age = value\n\nclass Person:\n\n    age = LoggedAgeAccess()             # Descriptor instance\n\n    def __init__(self, name, age):\n        self.name = name                # Regular instance attribute\n        self.age = age                  # Calls __set__()\n\n    def birthday(self):\n        self.age += 1                   # Calls both __get__() and __set__()\n        ",
#  'logging': <module 'logging' from '/Users/rohan/opt/miniconda3/envs/ML/lib/python3.9/logging/__init__.py'>,
#  'LoggedAgeAccess': __main__.LoggedAgeAccess,
#  'Person': __main__.Person,
#  '_i59': "mary = Person('Mary M', 30)",
#  'mary': <__main__.Person at 0x1100ab370>,
#  '_i60': "mary = Person('Mary M', 30)\ndave = Person('David D', 40)",
#  'dave': <__main__.Person at 0x106d9ed30>,
#  '_i61': "mary = Person('Mary M', 30)\ndave = Person('David D', 40)\nvars(mary)",
#  '_61': {'name': 'Mary M', '_age': 30},
#  '_i62': "mary = Person('Mary M', 30)\ndave = Person('David D', 40)\nmary.age\nvars(mary)",
#  '_62': {'name': 'Mary M', '_age': 30},
#  '_i63': "mary = Person('Mary M', 30)\ndave = Person('David D', 40)\nmary.age\nmary.birthday()\nvars(mary)",
#  '_63': {'name': 'Mary M', '_age': 31},
#  '_i64': "import logging\n\nlogging.basicConfig(level=logging.INFO)\n\nclass LoggedAccess:\n\n    def __set_name__(self, owner, name):\n        self.public_name = name\n        self.private_name = '_' + name\n\n    def __get__(self, obj, objtype=None):\n        value = getattr(obj, self.private_name)\n        logging.info('Accessing %r giving %r', self.public_name, value)\n        return value\n\n    def __set__(self, obj, value):\n        logging.info('Updating %r to %r', self.public_name, value)\n        setattr(obj, self.private_name, value)\n\nclass Person:\n\n    name = LoggedAccess()                # First descriptor instance\n    age = LoggedAccess()                 # Second descriptor instance\n\n    def __init__(self, name, age):\n        self.name = name                 # Calls the first descriptor\n        self.age = age                   # Calls the second descriptor\n\n    def birthday(self):\n        self.age += 1",
#  'LoggedAccess': __main__.LoggedAccess,
#  '_i65': "vars(vars(Person)['name'])",
#  '_65': {'public_name': 'name', 'private_name': '_name'},
#  '_i66': "vars(vars(Person)['name'])\nvars(vars(Person)['age'])",
#  '_66': {'public_name': 'age', 'private_name': '_age'},
#  '_i67': "vars(vars(Person)['name'])",
#  '_67': {'public_name': 'name', 'private_name': '_name'},
#  '_i68': "vars(vars(Person)['age'])",
#  '_68': {'public_name': 'age', 'private_name': '_age'},
#  '_i69': "mary = Person('Mary M', 30)\ndave = Person('David D', 40)\nmary.age\nmary.birthday()\nvars(mary)['age']",
#  '_i70': "mary = Person('Mary M', 30)\ndave = Person('David D', 40)\nmary.age\nmary.birthday()\nvars(mary)",
#  '_70': {'_name': 'Mary M', '_age': 31},
#  '_i71': "mary = Person('Mary M', 30)\ndave = Person('David D', 40)\nmary.age\nmary.birthday()\nvars(mary)['_age']",
#  '_71': 31,
#  '_i72': "mary = Person('Mary M', 30)\ndave = Person('David D', 40)\nmary.age\nmary.birthday()\nvars(mary)",
#  '_72': {'_name': 'Mary M', '_age': 31},
#  '_i73': "vars(Person)['name']",
#  '_73': <__main__.LoggedAccess at 0x106d9e040>,
#  '_i74': 'from utils.collections import AttrDict',
#  '_i75': 'from collections import AttrDict',
#  '_i76': 'vars()',
#  '_76': {...},
#  '_i77': 'locals()'}
